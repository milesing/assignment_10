# %%
import pandas as pd

# %%
#my original test function, for some reason it wouldn't act on 
#variables created in my sort function. So instead I included
#defining and calling my test function in my sort function.
def test_sort_data1(table):
    assert len(new_table.columns) == 5

# %%
#There are a couple datasets from the paper in the same format
#This function pulls out the columns that I want for my project
def sort_data(data):
    '''A function to take my datasets and extract the useful information'''
    #this is my test function, it makes sure there are the correct
    #number of columns
    def test_sort_data1(table):
        assert len(new_table.columns) == 5,'There should be five columns.'
    #First I grab the dataset. 
    table = pd.read_excel(data)
    #Then I define a new table with only the relevant columns
    new_table = table[['gene','sample_1','value_1','sample_2','value_2']] 
    #calling test function
    test_sort_data1(new_table)
    #setting index to gene
    new_table.set_index('gene')
    return new_table

# %%
#running sort function
sort_data('journal.pone.0112102.s005 - Copy.XLSX')
# Out:
#              gene sample_1     value_1 sample_2      value_2
# 0          21ur-1      ref    0.000000      NSM     0.000000
# 1         21ur-10      ref    0.000000      NSM     0.000000
# 2        21ur-100      ref    0.000000      NSM     0.000000
# 3       21ur-1000      ref    0.000000      NSM     0.000000
# 4      21ur-10000      ref    0.000000      NSM     0.000000
# 5      21ur-10001      ref    0.000000      NSM     0.000000
# 6      21ur-10002      ref    0.000000      NSM     0.000000
# 7      21ur-10003      ref    0.000000      NSM     0.000000
# 8      21ur-10004      ref    0.000000      NSM     0.000000
# 9      21ur-10005      ref    0.000000      NSM     0.000000
# 10     21ur-10007      ref    0.000000      NSM     0.000000
# 11     21ur-10009      ref    0.000000      NSM     0.000000
# 12      21ur-1001      ref    0.000000      NSM     0.000000
# 13     21ur-10011      ref    0.000000      NSM     0.000000
# ...
